# %% [markdown]
# # Remote data access using pandas

# %% [markdown]
# ### Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import os
from datetime import datetime
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
#import mplfinance as mpf
import seaborn as sns

# %% [markdown]
# ## Descargar las empresas que forman el SP500 de la wikipedia

# %%
sp_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_constituents = pd.read_html(sp_url, header=0)[0]

# %%
sp500_constituents
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                         Biotechnology  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# ### Descargar las empresas del IBEX35

# %%
#Ejemplo del Ibex 35 de la página de Sabadell
ibex_url = 'https://www.bsmarkets.com/cs/Satellite?cid=1191407146076&pagename=BSMarkets2%2FPage%2FPage_Interna_WFG_Template&language=es_ES'
#tiene varias tablas debemos especificar la que queremos llevar al DF
ibex35_constituents = pd.read_html(ibex_url)

# %%
ibex35_constituents
# Out:
# [  Mayores subidas: Mayores subidas:.1
#  0              GRF            +3,32 %
#  1              ITX            +1,48 %
#  2              IDR            +1,43 %,
#    Mayores bajadas: Mayores bajadas:.1
#  0              RED            -1,09 %
#  1             NTGY            -0,81 %
#  2              TEF            -0,70 %,
#                             TÃ­tulo   TKR  IntradÃ­a   Precio  Var. (%)  \
#  0                          ACCIONA   ANA        NaN  1326000        26
#  1                  ACCIONA ENERGIA   ANE        NaN   278800         7
#  2                      ACERINOX SA   ACX        NaN   106100        86
#  3                              ACS   ACS        NaN   392600       -10
#  4                             AENA  AENA        NaN  1638500        37
#  5                          AMADEUS   AMS        NaN   657600        61
#  6                    ARCELORMITTAL   MTS        NaN   261400       -57
#  7          BANCO DE BILBAO VIZCAYA  BBVA        NaN    82540         5
#  8                BANCO DE SABADELL   SAB        NaN    11205       -22
#  9                  BANCO SANTANDER   SAN        NaN    37890         3
#  10                       BANKINTER   BKT        NaN    58020       -17
#  11                       CAIXABANK  CABK        NaN    37350       -29
#  12                 CELLNEX TELECOM  CLNX        NaN   356600        -8
#  13                          ENAGAS   ENG        NaN   166700       -48
#  14                          ENDESA   ELE        NaN   195050        72
#  15                    FERROVIAL SE   FER        NaN   324600        62
#  16                         FLUIDRA   FDR        NaN   190800       122
#  17                    GRIFOLS CL.A   GRF        NaN   143000       332
#  18                       IAG GROUP   IAG        NaN    18405       107
#  19                       IBERDROLA   IBE        NaN   118350       120
#  20                         INDITEX   ITX        NaN   389800       148
#  21                  INDRA SISTEMAS   IDR        NaN   141600       143
#  22           INMOBILIARIA COLONIAL   COL        NaN    65200        38
#  23  LABORATORIOS FARMACEUTICOS ROV  ROVI        NaN   575500        26
#  24                LOGISTA HOLDINGS   LOG        NaN   241400        50
#  25                          MAPFRE   MAP        NaN    19530        15
#  26                    MELIA HOTELS   MEL        NaN    61950        73
#  27               MERLIN PROPERTIES   MRL        NaN    99500        91
#  28                  NATURGY ENERGY  NTGY        NaN   270000       -81
#  29                     REDEIA CORP   RED        NaN   150300      -109
#  30                          REPSOL   REP        NaN   135050       -52
#  31              SACYR VALLEHERMOSO  SCYR        NaN    31520        51
#  32  SOLARIA ENERGIA Y MEDIO AMBIEN   SLR        NaN   183100       113
#  33                      TELEFONICA   TEF        NaN    35670       -70
#  34                   UNICAJA BANCO   UNI        NaN     9060       -17
#
#      Var. (â¬)    MÃ¡x.    MÃ­n.     Volumen   Hora
#  0         3500  1342000  1322000      28.843  17:02
#  1          200   281800   275200     159.529  17:07
#  2          900   106250   104850     482.886  17:07
#  3         -400   395100   392200     102.606  17:08
#  4         6000  1643500  1623000      26.706  17:09
#  5         4000   659200   650600     192.443  17:09
#  6        -1500   263300   259450     210.090  17:08
#  7           40    82880    81700   3.613.807  17:09
#  8          -25    11240    11110  16.711.944  17:09
#  9           10    37995    37605  11.432.697  17:08
#  10        -100    58340    57640   1.255.185  17:08
#  11        -110    37740    37060   4.967.528  17:09
#  12        -300   361200   354700     294.279  17:08
#  13        -800   168050   166350     662.936  17:08
#  14        1400   195150   193600     251.927  17:08
#  15        2000   325200   321900     245.531  17:06
#  16        2300   191200   188100     148.873  17:09
#  17        4600   143150   138700     786.167  17:07
#  18         195    18405    18060   4.915.139  17:08
#  19        1400   118900   117200   3.869.857  17:08
#  20        5700   390300   381400     592.008  17:08
#  21        2000   141700   139400     179.170  17:08
#  22         250    65800    64800     570.002  17:07
#  23        1500   579000   573500      38.147  16:56
#  24        1200   241600   239600      97.764  17:08
#  25          30    19610    19440   1.277.118  17:06
#  26         450    62400    61400     326.568  17:08
#  27         900   100100    98800     263.406  17:08
#  28       -2200   272800   269400     215.869  17:01
#  29       -1650   152650   150100     471.785  17:07
#  30        -700   135400   134450   1.050.811  17:08
#  31         160    31680    31260   1.837.701  17:02
#  32        2050   183200   179350     193.574  17:09
#  33        -250    36060    35560   6.514.095  17:08
#  34         -15     9080     9000   7.306.801  17:05  ,
#      0               1          2   3
#  0 NaN             NaN        NaN NaN
#  1 NaN  Mis preferidos        NaN NaN
#  2 NaN       Editarlos  Editarlos NaN
#  3 NaN             NaN        NaN NaN,
#             0          1          2
#  0  Editarlos  Editarlos  Editarlos,
#      0                                                  1   2
#  0 NaN                                                NaN NaN
#  1 NaN  Siga la evoluciÃ³n de los Ã­ndices y valores e... NaN
#  2 NaN                                                NaN NaN,
#      0                                                  1   2
#  0 NaN                                                NaN NaN
#  1 NaN                           Ãltimas noticiasIbex 35 NaN
#  2 NaN  Ibex 35: Naturgy (-0,96%) y Redeia (-0,82%) so... NaN
#  3 NaN                                                NaN NaN]

# %%
#Los valores estan en el tabla 2
ibex35_constituents = pd.read_html(ibex_url, header=0)[2]
ibex35_constituents
# Out:
#                            TÃ­tulo   TKR  IntradÃ­a   Precio  Var. (%)  \
# 0                          ACCIONA   ANA        NaN  1326000        26
# 1                  ACCIONA ENERGIA   ANE        NaN   278800         7
# 2                      ACERINOX SA   ACX        NaN   106100        86
# 3                              ACS   ACS        NaN   392800        -5
# 4                             AENA  AENA        NaN  1638500        37
# 5                          AMADEUS   AMS        NaN   657600        61
# 6                    ARCELORMITTAL   MTS        NaN   261300       -61
# 7          BANCO DE BILBAO VIZCAYA  BBVA        NaN    82540         5
# 8                BANCO DE SABADELL   SAB        NaN    11195       -31
# 9                  BANCO SANTANDER   SAN        NaN    37905         7
# 10                       BANKINTER   BKT        NaN    58020       -17
# 11                       CAIXABANK  CABK        NaN    37350       -29
# 12                 CELLNEX TELECOM  CLNX        NaN   356600        -8
# 13                          ENAGAS   ENG        NaN   166650       -51
# 14                          ENDESA   ELE        NaN   195050        72
# 15                    FERROVIAL SE   FER        NaN   324800        68
# 16                         FLUIDRA   FDR        NaN   190800       122
# 17                    GRIFOLS CL.A   GRF        NaN   142950       329
# 18                       IAG GROUP   IAG        NaN    18410       110
# 19                       IBERDROLA   IBE        NaN   118300       115
# 20                         INDITEX   ITX        NaN   389800       148
# 21                  INDRA SISTEMAS   IDR        NaN   141600       143
# 22           INMOBILIARIA COLONIAL   COL        NaN    65200        38
# 23  LABORATORIOS FARMACEUTICOS ROV  ROVI        NaN   575500        26
# 24                LOGISTA HOLDINGS   LOG        NaN   241200        42
# 25                          MAPFRE   MAP        NaN    19550        26
# 26                    MELIA HOTELS   MEL        NaN    62000        81
# 27               MERLIN PROPERTIES   MRL        NaN    99550        96
# 28                  NATURGY ENERGY  NTGY        NaN   270000       -81
# 29                     REDEIA CORP   RED        NaN   150350      -105
# 30                          REPSOL   REP        NaN   135100       -48
# 31              SACYR VALLEHERMOSO  SCYR        NaN    31560        64
# 32  SOLARIA ENERGIA Y MEDIO AMBIEN   SLR        NaN   182850        99
# 33                      TELEFONICA   TEF        NaN    35670       -70
# 34                   UNICAJA BANCO   UNI        NaN     9060       -17
#
#     Var. (â¬)    MÃ¡x.    MÃ­n.     Volumen   Hora
# 0         3500  1342000  1322000      28.843  17:02
# 1          200   281800   275200     160.662  17:11
# 2          900   106250   104850     486.546  17:09
# 3         -200   395100   392200     103.314  17:10
# 4         6000  1643500  1623000      26.706  17:09
# 5         4000   659200   650600     193.213  17:10
# 6        -1600   263300   259450     210.595  17:10
# 7           40    82880    81700   3.617.633  17:10
# 8          -35    11240    11110  16.851.148  17:10
# 9           25    37995    37605  11.557.783  17:10
# 10        -100    58340    57640   1.255.962  17:10
# 11        -110    37740    37060   4.990.508  17:11
# 12        -300   361200   354700     295.102  17:10
# 13        -850   168050   166350     665.311  17:10
# 14        1400   195150   193600     252.731  17:11
# 15        2200   325200   321900     246.729  17:09
# 16        2300   191200   188100     148.873  17:09
# 17        4550   143150   138700     787.355  17:10
# 18         200    18410    18060   4.937.972  17:10
# 19        1350   118900   117200   3.886.786  17:10
# 20        5700   390300   381400     592.422  17:10
# 21        2000   141700   139400     179.170  17:08
# 22         250    65800    64800     570.002  17:07
# 23        1500   579000   573500      38.147  16:56
# 24        1000   241600   239600      99.747  17:10
# 25          50    19610    19440   1.285.541  17:10
# 26         500    62400    61400     333.692  17:10
# 27         950   100100    98800     265.552  17:10
# 28       -2200   272800   269400     215.869  17:01
# 29       -1600   152650   150100     474.650  17:11
# 30        -650   135400   134450   1.057.170  17:09
# 31         200    31680    31260   1.857.398  17:10
# 32        1800   183200   179350     197.103  17:10
# 33        -250    36060    35560   6.530.283  17:11
# 34         -15     9080     9000   7.327.201  17:09

# %% [markdown]
# ### Symbol de Zimmer Biomet

# %%
sp500_constituents.columns
# Out:
# Index(['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry',
#        'Headquarters Location', 'Date added', 'CIK', 'Founded'],
#       dtype='object')

# %%
symbol_sol = sp500_constituents[sp500_constituents["Security"] == "Zimmer Biomet"]
symbol_sol
# Out:
#     Symbol       Security  GICS Sector      GICS Sub-Industry  \
# 500    ZBH  Zimmer Biomet  Health Care  Health Care Equipment
#
#     Headquarters Location  Date added      CIK Founded
# 500       Warsaw, Indiana  2001-08-07  1136869    1927

# %% [markdown]
# ### 5 empresas mas antiguas del SP500

# %%
sp500_constituents.sort_values(by=['Date added'], inplace=True, ascending=True)

# %%
sp500_constituents.head(5)
# Out:
#     Symbol                 Security       GICS Sector  \
# 0      MMM                       3M       Industrials
# 380     PG         Procter & Gamble  Consumer Staples
# 84     CPB    Campbell Soup Company  Consumer Staples
# 74     BMY     Bristol Myers Squibb       Health Care
# 118     KO  Coca-Cola Company (The)  Consumer Staples
#
#                          GICS Sub-Industry    Headquarters Location  \
# 0                 Industrial Conglomerates    Saint Paul, Minnesota
# 380                 Personal Care Products         Cincinnati, Ohio
# 84                  Packaged Foods & Meats       Camden, New Jersey
# 74                         Pharmaceuticals  New York City, New York
# 118  Soft Drinks & Non-alcoholic Beverages         Atlanta, Georgia
#
#      Date added    CIK      Founded
# 0    1957-03-04  66740         1902
# 380  1957-03-04  80424         1837
# 84   1957-03-04  16732         1869
# 74   1957-03-04  14272  1989 (1887)
# 118  1957-03-04  21344         1886

# %% [markdown]
# ## Pandas-datareader for Market Data. FRED

# %% [markdown]
# Podemos acceder a las siguientes fuentes de datos:
#     -Tiingo
#     -IEX
#     -Alpha Vantage
#     -Econdb
#     -Enigma
#     -Quandl
#     -St.Louis FED (FRED)
#     -Kenneth Frenchs data library
#     -World Bank
#     -OECD
#     -Eurostat
#     -Thrift Savings Plan
#     -Nasdaq Trader symbol definitions
#     -Stooq
#     -MOEX
#     -Naver Finance
#     -Yahoo Finance

# %% [markdown]
# ### Descargar los valores de PIB de USA del año 2022

# %%
import pandas_datareader.data as web    # pandas 0.19.x and later
import datetime
# seleccionames fechas y GDP como variable
start = datetime.datetime(2022, 1, 1)
end = datetime.datetime(2022, 12, 31)
gdp = web.DataReader("GDP", "fred", start, end)

# %%
gdp
# Out:
#                   GDP
# DATE
# 2022-01-01  25029.116
# 2022-04-01  25544.273
# 2022-07-01  25994.639
# 2022-10-01  26408.405

# %% [markdown]
# ### Descarga el Índice del precio al consumo de consumidores urbanos y el de todos los productos menos comida y energía en ciudades de USA del año 2022

# %%
# url de FRED: https://fred.stlouisfed.org/series/CPILFESL
# Consumer Price Index for All Urban Consumers: All Items Less Food and Energy in U.S. City Average (CPILFESL)
start = datetime.datetime(2022, 1, 1)
end = datetime.datetime(2022, 12, 31)
CPILFESL = web.DataReader("CPILFESL", "fred", start, end)
#Los ultimos 3 registros, último trimestre
CPILFESL.tail(3)
# Out:
#             CPILFESL
# DATE
# 2022-10-01   299.333
# 2022-11-01   300.261
# 2022-12-01   301.460

# %% [markdown]
# ## Yahoo Finance

# %% [markdown]
# ### Último año de datos diarios de Microsoft

# %%
import yfinance as yf

symbol = 'MSFT'
ticker = yf.Ticker(symbol)
df_msft = ticker.history(period = '365d',
                    interval = '1d',
                    actions=True,
                    auto_adjust=True)

# %%
df_msft
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-07-11 00:00:00-04:00  262.019087  262.887064  258.596513  260.894684
# 2022-07-12 00:00:00-04:00  262.245955  262.305133  248.595109  250.202835
# 2022-07-13 00:00:00-04:00  246.770359  250.084435  244.718787  249.265778
# 2022-07-14 00:00:00-04:00  247.145174  251.652702  242.578453  250.607193
# 2022-07-15 00:00:00-04:00  252.224774  256.811210  251.287761  253.211105
# ...                               ...         ...         ...         ...
# 2023-12-13 00:00:00-05:00  376.019989  377.640015  370.769989  374.369995
# 2023-12-14 00:00:00-05:00  373.309998  373.760010  364.130005  365.929993
# 2023-12-15 00:00:00-05:00  366.850006  372.399994  366.279999  370.730011
# 2023-12-18 00:00:00-05:00  369.450012  373.000000  368.679993  372.649994
# 2023-12-19 00:00:00-05:00  371.489990  373.260010  369.839996  373.260010
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-07-11 00:00:00-04:00  19455200        0.0           0.0
# 2022-07-12 00:00:00-04:00  35868500        0.0           0.0
# 2022-07-13 00:00:00-04:00  29497400        0.0           0.0
# 2022-07-14 00:00:00-04:00  25102800        0.0           0.0
# 2022-07-15 00:00:00-04:00  29774100        0.0           0.0
# ...                             ...        ...           ...
# 2023-12-13 00:00:00-05:00  30955500        0.0           0.0
# 2023-12-14 00:00:00-05:00  43277500        0.0           0.0
# 2023-12-15 00:00:00-05:00  78478200        0.0           0.0
# 2023-12-18 00:00:00-05:00  21802900        0.0           0.0
# 2023-12-19 00:00:00-05:00  20580600        0.0           0.0
#
# [365 rows x 7 columns]

# %% [markdown]
# ### Gráfico de MSFT último año

# %%
# Con Pandas podemos pintar directamente
# eje y = valores de Close
# eje x = valores del index (fecha)
# atributo lw es el grosor de la linea
df_msft.plot.line(y='Close',figsize=(12,3),lw=1);

df_msft.plot.line(y='Close', f)

# %%
import matplotlib.pyplot as plt

# Extract the date and close price columns
closing_price = df_msft['Close']

plt.plot(closing_price, color='red', linewidth=1)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('MSFT Stock Price')

# Add the grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### Datos Mensuales de Google 2018-2021

# %%
# especificar fechas, periodo de 1mo y symbol
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2021, 12, 31)
symbol = 'GOOG'
ticker = yf.Ticker(symbol)
df_goog = ticker.history(start=start,
                         end=end,
                    interval = '1mo',
                    actions=True,
                    auto_adjust=True)

# %%
df_goog.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-01-01 00:00:00-05:00  52.417000  59.344501  52.261501  58.497002
# 2018-02-01 00:00:00-05:00  58.130501  58.700001  49.627998  55.236500
# 2018-03-01 00:00:00-05:00  55.393501  58.852501  49.032001  51.589500
# 2018-04-01 00:00:00-04:00  51.140999  54.708248  49.518501  50.866501
# 2018-05-01 00:00:00-04:00  50.682999  55.537498  50.314499  54.249500
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-01-01 00:00:00-05:00  574768000        0.0           0.0
# 2018-02-01 00:00:00-05:00  847640000        0.0           0.0
# 2018-03-01 00:00:00-05:00  907066000        0.0           0.0
# 2018-04-01 00:00:00-04:00  834318000        0.0           0.0
# 2018-05-01 00:00:00-04:00  636988000        0.0           0.0

# %% [markdown]
# ## Nasdaq Symbols

# %% [markdown]
# In pandas_datareader/nasdaq_trader.py, change
#
#     with warnings.catch_warnings(record=True):
#         data = read_csv(
#             StringIO("\n".join(lines[:-1])),
#             "|",
#             dtype=_TICKER_DTYPE,
#             converters=converter_map,
#             index_col=1,
#         )
# to
#
#     with warnings.catch_warnings(record=True):
#         data = read_csv(
#             StringIO("\n".join(lines[:-1])),
#             sep="|",
#             dtype=_TICKER_DTYPE,
#             converters=converter_map,
#             index_col=1,
#         )

# %%
# Pandas Data reader tiene una funcionalidad específica
# Importamos
from pandas_datareader.nasdaq_trader import get_nasdaq_symbols
symbols = get_nasdaq_symbols()
symbols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11172 entries, A to ZYXI
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     11172 non-null  bool
#  1   Security Name     11172 non-null  object
#  2   Listing Exchange  11172 non-null  category
#  3   Market Category   11172 non-null  object
#  4   ETF               11172 non-null  bool
#  5   Round Lot Size    11172 non-null  float64
#  6   Test Issue        11172 non-null  bool
#  7   Financial Status  5021 non-null   category
#  8   CQS Symbol        6151 non-null   object
#  9   NASDAQ Symbol     11171 non-null  object
#  10  NextShares        11172 non-null  bool
# dtypes: bool(4), category(2), float64(1), object(4)
# memory usage: 589.6+ KB

# %%
# filtro solo los ETF
symbols[symbols.ETF == True]
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AADR             True                AdvisorShares Dorsey Wright ADR ETF
# AAPB             True            GraniteShares 1.75x Long AAPL Daily ETF
# AAPD             True                 Direxion Daily AAPL Bear 1X Shares
# ...               ...                                                ...
# ZROZ             True  PIMCO 25  Year Zero Coupon U.S. Treasury Index...
# ZSB              True  USCF ETF Trust USCF Sustainable Battery Metals...
# ZSC              True  USCF ETF Trust USCF Sustainable Commodity Stra...
# ZSL              True                        ProShares UltraShort Silver
# ZTAX             True  X-Square Series Trust X-Square Municipal Incom...
#
#        Listing Exchange Market Category   ETF  Round Lot Size  Test Issue  \
# Symbol
# AAA                   P                  True           100.0       False
# AAAU                  Z                  True           100.0       False
# AADR                  Q               G  True           100.0       False
# AAPB                  Q               G  True           100.0       False
# AAPD                  Q               G  True           100.0       False
# ...                 ...             ...   ...             ...         ...
# ZROZ                  P                  True           100.0       False
# ZSB                   P                  True           100.0       False
# ZSC                   P                  True           100.0       False
# ZSL                   P                  True           100.0       False
# ZTAX                  P                  True           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# AAA                 NaN        AAA           AAA       False
# AAAU                NaN       AAAU          AAAU       False
# AADR                  N        NaN          AADR       False
# AAPB                  N        NaN          AAPB       False
# AAPD                  N        NaN          AAPD       False
# ...                 ...        ...           ...         ...
# ZROZ                NaN       ZROZ          ZROZ       False
# ZSB                 NaN        ZSB           ZSB       False
# ZSC                 NaN        ZSC           ZSC       False
# ZSL                 NaN        ZSL           ZSL       False
# ZTAX                NaN       ZTAX          ZTAX       False
#
# [3335 rows x 11 columns]
